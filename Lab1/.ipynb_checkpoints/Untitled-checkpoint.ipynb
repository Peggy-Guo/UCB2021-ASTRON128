# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# !conda list
# Out:
# # packages in environment at F:\python:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2019.10                  py36_0
# _ipyw_jlab_nb_ext_conf    0.1.0            py36he6757f0_0
# _tflow_select             2.2.0                     eigen
# absl-py                   0.11.0           py36haa95532_0
# alabaster                 0.7.10           py36hcd07829_0
# anaconda                  custom                   py36_1
# anaconda-client           1.6.14                   py36_0
# anaconda-navigator        1.8.7                    py36_0
# anaconda-project          0.8.2            py36hfad2e28_0
# arrow                     0.17.0                   pypi_0    pypi
# arviz                     0.11.2                   pypi_0    pypi
# asgiref                   3.2.3                    pypi_0    pypi
# asn1crypto                0.24.0                   py36_0
# astor                     0.8.1                    py36_0
# ...

# %%
import pymc3
# Out:
# You can find the C code in this temporary file: C:\Users\admin\AppData\Local\Temp\theano_compilation_error_78caw86p
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# F:\python\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#      79                 "Extra debug information: force_compile=%s, _need_reload=%s"
# ---> 80                 % (version, actual_version, force_compile, _need_reload)
#      81             )
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# F:\python\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#     103                     " _need_reload=%s"
# ...

# %%
import corner
